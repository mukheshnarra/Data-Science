# %%
import zipfile
import os
import pandas as pd

# %%
if(os.path.isdir('C:/Users/MUKHESH/OneDrive/Documents/Python Scripts/Recommendation/data')==0):
    os.mkdir('C:/Users/MUKHESH/OneDrive/Documents/Python Scripts/Recommendation/data')
    zip_ref_movies=zipfile.ZipFile('C:/Users/MUKHESH/Downloads/tmdb_5000_movies.csv.zip')
    zip_ref_credits=zipfile.ZipFile('C:/Users/MUKHESH/Downloads/tmdb_5000_credits.csv.zip')
    zip_ref_movies.extractall('C:/Users/MUKHESH/OneDrive/Documents/Python Scripts/Recommendation/data')
    zip_ref_credits.extractall('C:/Users/MUKHESH/OneDrive/Documents/Python Scripts/Recommendation/data')
    zip_ref_movies.close()
    zip_ref_credits.close()
os.chdir('C:/Users/MUKHESH/OneDrive/Documents/Python Scripts/Recommendation/data')

# %%
credits=pd.read_csv('tmdb_5000_credits.csv')
movies=pd.read_csv('tmdb_5000_movies.csv')

# %%
credits.tail(5)
# Out:
#           id                      title  \
# 4798    9367                El Mariachi
# 4799   72766                  Newlyweds
# 4800  231617  Signed, Sealed, Delivered
# 4801  126186           Shanghai Calling
# 4802   25975          My Date with Drew
#
#                                                    cast  \
# 4798  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 4798  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4799  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4800  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4801  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4802  [{"credit_id": "58ce021b9251415a390165d9", "de...

# %%
movies.tail(5)
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %%
credits.rename(columns={'movie_id':'id'},inplace='True')

# %%
recommendation=movies.merge(credits,on="id")

# %%
recommendation.tail(5)
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...
